# %%
import os
import re
import pandas as pd
import codecs
from getpass import getpass
import imaplib
import email
from bs4 import BeautifulSoup
from nltk import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

"""qmepjfnurwnxhvup"""
# Out:
# 'qmepjfnurwnxhvup'

# %%
class EmailClassifier:
    CATEGORIES = {
        'education': ['course', 'university', 'lecture', 'assignment', 'professor', 'school', 'college'],
        'business': ['meeting', 'report', 'client', 'project', 'deadline', 'work', 'office'],
        'personal': ['family', 'friend', 'dinner', 'weekend', 'photos', 'birthday', 'holiday'],
        'promotions': ['deal', 'offer', 'discount', 'sale', 'limited', 'coupon', 'promo'],
        'other': []
    }

    def __init__(self):
        self.vectorizer = TfidfVectorizer()
        self.model = MultinomialNB()
        self._train_model()

    def _train_model(self):
        """Train a simple text classifier"""
        texts = []
        labels = []
        for category, keywords in self.CATEGORIES.items():
            texts.extend(keywords)
            labels.extend([category]*len(keywords))
        
        X = self.vectorizer.fit_transform(texts)
        self.model.fit(X, labels)

    def predict(self, text):
        """Predict email category"""
        if not text.strip():
            return 'other'
        vec = self.vectorizer.transform([text])
        return self.model.predict(vec)[0]

# %%
class EmailProcessor:
    def __init__(self, username, password):
        self.mail = imaplib.IMAP4_SSL('imap.gmail.com')
        self.mail.socket().settimeout(300)
        self.classifier = EmailClassifier()
        self.mail.login(username, password)

    def get_emails(self, folder='INBOX', limit=100):
        """Fetch emails from specified folder"""
        self.mail.select(folder, readonly=True)
        _, data = self.mail.uid('search', None, 'ALL')
        uids = data[0].decode('utf-8').split()[:limit]
        return [self._parse_email(uid) for uid in uids]

    def _parse_email(self, uid):
        """Parse individual email with category detection"""
        _, data = self.mail.uid('fetch', uid, '(RFC822)')
        msg = email.message_from_bytes(data[0][1])
        
        email_data = {
            'From': msg['From'],
            'Subject': msg['Subject'],
            'Body': self._extract_body(msg),
            'Folder': 'INBOX'  # Default, updated later
        }
        
        # Add category prediction
        content = f"{email_data['Subject']} {email_data['Body']}"
        email_data['Category'] = self.classifier.predict(content)
        
        return email_data

    def _extract_body(self, msg):
        """Extract and clean email body"""
        body = ""
        for part in msg.walk():
            if part.get_content_type() in ['text/plain', 'text/html']:
                try:
                    payload = part.get_payload(decode=True)
                    text = payload.decode('utf-8', 'ignore')
                    if part.get_content_type() == 'text/html':
                        text = BeautifulSoup(text, 'html5lib').get_text()
                    body += text
                except Exception:
                    continue
        return self._clean_text(body)

    def _clean_text(self, text):
        """Clean email text for analysis"""
        text = re.sub(r'<[^>]+>', '', text)
        text = re.sub(r'\s+', ' ', text)
        words = [w for w in word_tokenize(text) 
                if len(w) <= 15 and re.match('[A-Za-z0-9]+', w)]
        return ' '.join(words)

# %%
class DataOrganizer:
    @staticmethod
    def categorize_emails(emails):
        """Sort emails into category buckets"""
        categories = {cat: [] for cat in EmailClassifier.CATEGORIES}
        for email in emails:
            categories[email['Category']].append(email)
        return categories

    @staticmethod
    def save_to_excel(categorized_emails, output_dir='Downloads'):
        """Save each category to separate Excel file"""
        os.makedirs(output_dir, exist_ok=True)
        for category, emails in categorized_emails.items():
            df = pd.DataFrame(emails)
            df.to_excel(f'{output_dir}/{category}_emails.xlsx', index=False)
            print(f"Saved {len(emails)} {category} emails")

# %%
def main():
    try:
        # Authentication
        email_id = input('Enter Gmail: ')
        password = getpass('Enter Password: ')
        
        # Initialize components
        processor = EmailProcessor(email_id, password)
        organizer = DataOrganizer()

        # Process emails
        print("\nFetching emails...")
        emails = processor.get_emails(limit=10)  # Process first 10 for demo
        
        # Categorize and save
        categorized = organizer.categorize_emails(emails)
        organizer.save_to_excel(categorized)
        
        # Print summary
        print("\nEmail Categories Summary:")
        for cat, items in categorized.items():
            print(f"{cat.title():<10}: {len(items)} emails")

    except Exception as e:
        print(f"\nError: {str(e)}")
        print("Check: 1) IMAP access 2) App Password if 2FA enabled")


if __name__ == '__main__':
    main()
# Out:
# Fetching emails...
#
# Error: command: UID => socket error: EOF
# Check: 1) IMAP access 2) App Password if 2FA enabled

# %%
import os
import imaplib
import pandas as pd
from getpass import getpass
import email
from email.header import decode_header

class RawEmailBackup:
    def __init__(self, username, password):
        self.mail = imaplib.IMAP4_SSL('imap.gmail.com')
        self.mail.login(username, password)
        self.base_dir = os.path.join(os.getcwd(), 'Downloads')
        
    def backup_raw_emails(self):
        """Backup raw emails by searching for matching subjects"""
        try:
            self.mail.select('INBOX', readonly=True)
            
            for category in ['business', 'education', 'personal', 'promotions']:
                excel_path = os.path.join(self.base_dir, f'{category}_emails.xlsx')
                
                if os.path.exists(excel_path):
                    print(f"\n📂 Backing up {category} emails...")
                    self._backup_by_subject(category, excel_path)
                    
        except Exception as e:
            print(f"⚠️ Error: {str(e)}")
        finally:
            self.mail.logout()

    def _backup_by_subject(self, category, excel_path):
        """Backup emails by matching subjects"""
        raw_dir = os.path.join(self.base_dir, f'{category}_raw')
        os.makedirs(raw_dir, exist_ok=True)
        
        try:
            df = pd.read_excel(excel_path)
            if 'Subject' not in df.columns:
                print(f"❌ No Subject column in {excel_path}")
                return
                
            success = 0
            
            for subject in df['Subject'].unique()[:10]:  # Limit to 10 unique subjects
                try:
                    # Search for emails with this subject
                    status, messages = self.mail.search(None, f'SUBJECT "{subject}"')
                    if status != 'OK':
                        continue
                        
                    for mail_id in messages[0].split()[:3]:  # Max 3 emails per subject
                        status, data = self.mail.fetch(mail_id, '(RFC822)')
                        if status == 'OK':
                            filename = f"{category}_{mail_id.decode()}.eml"
                            with open(os.path.join(raw_dir, filename), 'wb') as f:
                                f.write(data[0][1])
                            success += 1
                            
                except Exception as e:
                    print(f"✗ Subject '{subject[:20]}...': {str(e)[:50]}")
                    
            print(f"✅ Saved {success} emails to {raw_dir}")
            
        except Exception as e:
            print(f"❌ Failed to process {category}: {str(e)}")

def main():
    print("\n📧 SUBJECT-BASED EMAIL BACKUP")
    print("---------------------------")
    print("Note: Will match emails by subject from Excel files")
    
    email = input("Your Gmail: ")
    password = getpass("Password: ")
    
    backup = RawEmailBackup(email, password)
    backup.backup_raw_emails()

if __name__ == '__main__':
    main()
# Out:
# 📧 SUBJECT-BASED EMAIL BACKUP
# ---------------------------
# Note: Will match emails by subject from Excel files
#
# 📂 Backing up business emails...
# ✗ Subject 'NTA - JEE(Main)-2022...': SEARCH command error: BAD [b'Could not parse comma
# ✗ Subject 'NTA - JEE(Main)-2022...': SEARCH command error: BAD [b'Could not parse comma
# ✗ Subject 'NTA - JEE(Main)-2022...': SEARCH command error: BAD [b'Could not parse comma
# ✅ Saved 10 emails to c:\Users\aspk1\OneDrive\Desktop\Gmail-Classification\Downloads\business_raw
#
# 📂 Backing up education emails...
# ✗ Subject 'ANUMALASETTY POORNA ...': SEARCH command error: BAD [b'Could not parse comma
# ✅ Saved 8 emails to c:\Users\aspk1\OneDrive\Desktop\Gmail-Classification\Downloads\education_raw
#
# 📂 Backing up personal emails...
# ✅ Saved 16 emails to c:\Users\aspk1\OneDrive\Desktop\Gmail-Classification\Downloads\personal_raw
#
# 📂 Backing up promotions emails...
# ✗ Subject 'IRCTC' s Online Rail...': SEARCH command error: BAD [b'Could not parse comma
# ✅ Saved 9 emails to c:\Users\aspk1\OneDrive\Desktop\Gmail-Classification\Downloads\promotions_raw

# %%
import os
import imaplib
import email
from getpass import getpass
import pandas as pd
from email.header import decode_header

class CompleteRawBackup:
    def __init__(self, username, password):
        self.mail = imaplib.IMAP4_SSL('imap.gmail.com')
        self.mail.login(username, password)
        self.base_dir = os.path.join(os.getcwd(), 'Raw_Emails_TXT')
        os.makedirs(self.base_dir, exist_ok=True)

    def backup_all_emails(self):
        """Backup ALL emails from all categories"""
        try:
            # Get all available folders
            status, folders = self.mail.list()
            if status != 'OK':
                raise Exception("Failed to list folders")
            
            for folder_info in folders:
                folder_name = self._parse_folder_name(folder_info.decode())
                if folder_name:
                    self._process_folder(folder_name)
                    
        except Exception as e:
            print(f"⚠️ Error: {str(e)}")
        finally:
            self.mail.logout()

    def _parse_folder_name(self, folder_info):
        """Extract folder name from IMAP response"""
        parts = folder_info.split(' "/" ')
        return parts[-1].strip('"') if len(parts) > 1 else None

    def _process_folder(self, folder_name):
        """Process all emails in one folder"""
        try:
            print(f"\n📂 Processing folder: {folder_name}")
            status = self.mail.select(folder_name, readonly=True)
            if status[0] != 'OK':
                return
                
            # Create category folder
            clean_name = folder_name.replace('[Gmail]/', '').replace('/', '_')
            category_dir = os.path.join(self.base_dir, clean_name)
            os.makedirs(category_dir, exist_ok=True)
            
            # Search ALL emails
            status, messages = self.mail.search(None, 'ALL')
            if status != 'OK':
                return
                
            for mail_id in messages[0].split():
                self._save_email(mail_id, category_dir)
                
        except Exception as e:
            print(f"✗ Error in {folder_name}: {str(e)[:50]}...")

    def _save_email(self, mail_id, category_dir):
        """Save individual email as TXT"""
        try:
            status, data = self.mail.fetch(mail_id, '(RFC822)')
            if status != 'OK':
                return
                
            msg = email.message_from_bytes(data[0][1])
            
            # Decode subject
            subject, encoding = decode_header(msg['Subject'])[0]
            if isinstance(subject, bytes):
                subject = subject.decode(encoding or 'utf-8', errors='replace')
            
            # Clean filename
            filename = f"{subject[:50]}_{mail_id.decode()}.txt".replace('/', '_')
            filepath = os.path.join(category_dir, filename)
            
            # Save complete raw email
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(f"From: {msg['From']}\n")
                f.write(f"To: {msg['To']}\n")
                f.write(f"Subject: {subject}\n")
                f.write(f"Date: {msg['Date']}\n\n")
                
                # Save body content
                if msg.is_multipart():
                    for part in msg.walk():
                        content_type = part.get_content_type()
                        if content_type in ['text/plain', 'text/html']:
                            try:
                                body = part.get_payload(decode=True).decode('utf-8', errors='replace')
                                f.write(body + "\n\n")
                            except:
                                continue
                else:
                    body = msg.get_payload(decode=True).decode('utf-8', errors='replace')
                    f.write(body)
            
            print(f"✓ Saved: {filename}")
            
        except Exception as e:
            print(f"✗ Failed email {mail_id}: {str(e)[:50]}...")

def main():
    print("\n📧 COMPLETE RAW EMAIL BACKUP")
    print("--------------------------")
    print("This will save ALL emails in TXT format")
    print("organized by Gmail folders\n")
    
    email = input("Your Gmail: ")
    password = getpass("Password: ")
    
    backup = CompleteRawBackup(email, password)
    backup.backup_all_emails()
    print(f"\n✅ All emails saved to: {os.path.abspath(backup.base_dir)}")

if __name__ == '__main__':
    main()
# Out:
# 📧 COMPLETE RAW EMAIL BACKUP
# --------------------------
# This will save ALL emails in TXT format
# organized by Gmail folders
#
#
# 📂 Processing folder: INBOX
# ✓ Saved: Poorna Kumar, finish setting up your new Google Ac_1.txt
# ✓ Saved: Your Google Account was recovered successfully_2.txt
# ✓ Saved: Security alert_3.txt
# ✓ Saved: NTA - JEE(Main)-2022 Session 1  0648976 Applicatio_4.txt
# ✓ Saved: NTA - JEE(Main)-2022 Session 1 E-Mail Verification_5.txt
# ✓ Saved: NTA - JEE(Main)-2022  Session 1  0648976 Applicati_6.txt
# ✓ Saved: NTA - JEE(Main)-2022  Session 1  0648976 Confirmat_7.txt
# ✓ Saved: Fwd:_8.txt
# ✓ Saved: AP EAPCET-2022 Payment Details_9.txt
# ✓ Saved: AP EAPCET - 2022 Application Details_10.txt
# ✓ Saved: TS EAMCET-2022 Payment Details_11.txt
# ✓ Saved: TS EAMCET-2022 Application Details_12.txt
# ✓ Saved: TS EAMCET-2022 Application Details_13.txt
# ✓ Saved: TS EAMCET-2022 _14.txt
# ✓ Saved: B.Tech. Admissions 2022 - Login Crendentials_15.txt
# ✓ Saved: Thank You ANUMALA SETTY PURNA KUMAR for Registerin_16.txt
# ✓ Saved: Application Fee Paid - VIT _17.txt
# ✓ Saved: Thank You ANUMALA SETTY PURNA KUMAR for submitting_18.txt
# ✓ Saved: Verify Your New Email aspk126@gmail.com_19.txt
# ✓ Saved: Account Details with HCL TechBee_20.txt
# ✓ Saved: Your Application HCLTB0205006 is submitted._21.txt
# ✓ Saved: Your Google Account was recovered successfully_22.txt
# ✓ Saved: Submit Application Form and Get Shortlisted - HCL _23.txt
# ✗ Failed email b'24': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Creating knowledge through research and innovation_25.txt
# ✓ Saved: ANUMALASETTY POORNA KUMAR Complete your applicatio_26.txt
# ✓ Saved: Forgot Password Request - B.Tech. Admissions-2022 _27.txt
# ✓ Saved: ✅ Poorna Kumar, finish setting up your Realme C15 _28.txt
# ✓ Saved: Have you ever thought of starting your own venture_29.txt
# ✓ Saved: Connect with us on WhatsApp_30.txt
# ✓ Saved: Password_31.txt
# ✗ Failed email b'32': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'33': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'34': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Re: venuvmcv@gmail.com_35.txt
# ✓ Saved: Have questions about TechBee - HCL's Early Career _36.txt
# ✓ Saved: Your home away from your home !_37.txt
# ✗ Failed email b'38': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Training and certifications in collaboration with _39.txt
# ✓ Saved: Why don't you predict your Scholarship and decide _40.txt
# ✗ Failed email b'41': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Your curriculum also needs innovation_42.txt
# ✓ Saved: e-admit card for VITEEE-2022_43.txt
# ✓ Saved: Everyone have different career aspirations, choose_44.txt
# ✗ Failed email b'45': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'46': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'47': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✓ Saved: Check how much scholarship you can get on the basi_48.txt
# ✓ Saved: Top 3 citizens of the country at LPU_49.txt
# ✗ Failed email b'50': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Be the part of amazing LPU community!!_51.txt
# ✓ Saved: Laboratories are the key requirements of a student_52.txt
# ✓ Saved: NTA - JEE(Main)-2022 Session 1 Forgot Password_53.txt
# ✓ Saved: NTA - JEE(Main) 2022 Session 2  Forgot Password_54.txt
# ✓ Saved: NTA - JEE(Main) 2022 Session 2  Forgot Password_55.txt
# ✓ Saved: NTA - JEE(Main) 2022 Session 2    0648976 Candidat_56.txt
# ✓ Saved: NTA - JEE(Main) 2022 Session 2    0648976 Confirma_57.txt
# ✓ Saved: NTA - JEE(Main) 2022 Session 2    0648976 Applicat_58.txt
# ✓ Saved: NTA - JEE(Main) 2022 Session 2    0648976 Confirma_59.txt
# ✗ Failed email b'60': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: VITEEE-2022 - RESULT -REG_61.txt
# ✓ Saved: Joint Entrance Examination (Main) - 2022 Session 1_62.txt
# ✓ Saved: VIT-NIRF- RANKING-REG_63.txt
# ✗ Failed email b'64': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Fortune 500 companies, MNCs are on lookout for tal_65.txt
# ✓ Saved: Admission to Top NITs_IIITs_GFTIs & Other Private _66.txt
# ✓ Saved: Joint Entrance Examination (Main) - 2022 Score Car_67.txt
# ✗ Failed email b'68': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Kalasalingam University_69.txt
# ✓ Saved: Fwd: Kalasalingam University_70.txt
# ✗ Failed email b'71': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Want To Check Your Admission Chances in Top Engine_72.txt
# ✓ Saved: Tips to deal with result stress_73.txt
# ✓ Saved: Greetings from Kalasalingam University!!_74.txt
# ✓ Saved: Ranked #5 among top Engineering colleges in India _75.txt
# ✗ Failed email b'76': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Confused about Your Admission Chances in Top Engin_77.txt
# ✓ Saved: JEE Main 2022 College Predictor : Know Your Engine_78.txt
# ✓ Saved: Email verification code: 695960_79.txt
# ✓ Saved: Your Google Account was recovered successfully_80.txt
# ✓ Saved: Security alert_81.txt
# ✓ Saved: Security alert_82.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_83.txt
# ✓ Saved: ✅ Poorna Kumar, finish setting up your Realme C15 _84.txt
# ✓ Saved: Make Your Preferred List of Engineering Colleges w_85.txt
# ✓ Saved: Lenskart power_86.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_87.txt
# ✓ Saved: Hurry Up.. Complete the Application and Start your_88.txt
# ✓ Saved: 🌎 You recently turned on Location History_89.txt
# ✗ Failed email b'90': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'91': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: New material: "Lecture 1 ppt"_92.txt
# ✗ Failed email b'93': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'94': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Hurry Up.. Complete the Application and Start your_95.txt
# ✓ Saved: Hurry Up.. Complete the Application and Start your_96.txt
# ✓ Saved: 211PHY1301 Unit I Magnetic materials Ex.1_97.txt
# ✓ Saved: How to get started with Coursera _98.txt
# ✓ Saved: New announcement: "Bring Rs 72_- for physics lab m_99.txt
# ✓ Saved: Finish a course in 48 hours ✔️_100.txt
# ✓ Saved: OTP for verification_101.txt
# ✓ Saved: e-PAN allotment request submitted sucessfully_102.txt
# ✓ Saved: ePAN Allotted successfully_103.txt
# ✓ Saved: ePAN Allotted successfully_104.txt
# ✓ Saved: ePAN Allotted successfully_105.txt
# ✓ Saved: ePAN Allotted successfully_106.txt
# ✓ Saved: ePAN Allotted successfully_107.txt
# ✓ Saved: ePAN Allotted successfully_108.txt
# ✓ Saved: ePAN Allotted successfully_109.txt
# ✓ Saved: ePAN Allotted successfully_110.txt
# ✓ Saved: ePAN Allotted successfully_111.txt
# ✓ Saved: ePAN Allotted successfully_112.txt
# ✓ Saved: ePAN Allotted successfully_113.txt
# ✓ Saved: ePAN Allotted successfully_114.txt
# ✓ Saved: ePAN Allotted successfully_115.txt
# ✓ Saved: ePAN Allotted successfully_116.txt
# ✓ Saved: ePAN Allotted successfully_117.txt
# ✓ Saved: Master the job skills you need for your career _118.txt
# ✓ Saved: Share request for ‘ᴀʙʜɪ(ʜᴏsᴛᴇʟ ᴀᴘᴘʟɪᴄᴀᴛɪᴏɴ)’_119.txt
# ✓ Saved: Welcome to join WPS Office_120.txt
# ✓ Saved: New material: "SYLLABUS"_121.txt
# ✓ Saved: Security alert_122.txt
# ✓ Saved: New announcement: "Unit I PPT and Study Materials"_123.txt
# ✓ Saved: Special offer: free courses to get you started_124.txt
# ✓ Saved: Recommended: Introduction to Psychology_125.txt
# ✓ Saved: New material: "Unit  II MECHANICS AND THERMODYNAMI_126.txt
# ✓ Saved: Degrees From Top Universities on Coursera _127.txt
# ✓ Saved: Recommended: The Science of Well-Being_128.txt
# ✓ Saved: New announcement: "Unit 2
#  Learning Materials"_129.txt
# ✓ Saved: New announcement: "UNIT 2 - PPT AND STUDY MATERIAL_130.txt
# ✓ Saved: Recommended: Technical Support Fundamentals_131.txt
# ✓ Saved: Interested in an MBA from South America's #1 most _132.txt
# ✓ Saved: Earn a career credential from Google, Meta and mor_133.txt
# ✓ Saved: Get started with your Master of Business Administr_134.txt
# ✓ Saved: Recommended: Google Data Analytics_135.txt
# ✓ Saved: Earn a top-ranked MBA from anywhere in the world_136.txt
# ✓ Saved: Get started with your Master of Business Administr_137.txt
# ✓ Saved: Develop high-impact skills for a digital future_138.txt
# ✓ Saved: Join us for a live webinar with IIM Nagpur on Octo_139.txt
# ✓ Saved: Recommended: Google Data Analytics_140.txt
# ✓ Saved: Make a valuable investment by enrolling in South A_141.txt
# ✓ Saved: New announcement: "Learning Materials for Units 3&_142.txt
# ✓ Saved: New announcement: "Learning Materials for Unit-5
# _143.txt
# ✓ Saved: Get started with your Master of Business Administr_144.txt
# ✓ Saved: Upskill and reskill teams with Academies_145.txt
# ✗ Failed email b'146': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Security alert_147.txt
# ✓ Saved: Poorna Kumar, take the next step on your Windows d_148.txt
# ✓ Saved: New assignment: "DRAW THE SKETCH AND SEND THE STEP_149.txt
# ✓ Saved: Courses for you_150.txt
# ✓ Saved: Empower teams with Essential Skills Collections_151.txt
# ✓ Saved: New announcement: "Midsem Practical- English For…"_152.txt
# ✓ Saved: Security alert_153.txt
# ✓ Saved: Interested in an MBA from South America's #1 most _154.txt
# ✓ Saved: Discover top job trends with the Coursera Skills R_155.txt
# ✓ Saved: Get started with your Master of Business Administr_156.txt
# ✓ Saved: Recommended: Python for Everybody_157.txt
# ✓ Saved: New announcement: "UNIT 3 PPT"_158.txt
# ✓ Saved: New announcement: "UNIT 4 PPT AND STUDY MATERIAL"_159.txt
# ✗ Failed email b'160': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Terms of Use Update_161.txt
# ✓ Saved: Recommended: Introduction to Psychology_162.txt
# ✓ Saved: Follow your curiosity..._163.txt
# ✓ Saved: Change Mi Account Email Address_164.txt
# ✓ Saved: Security alert_165.txt
# ✓ Saved: Recommended: The Science of Well-Being_166.txt
# ✓ Saved: New announcement: "BIOLOGY ALL UNITS DRIVE LINK
# …_167.txt
# ✓ Saved: Your form, PUNCHING MACHINE, has new responses._168.txt
# ✓ Saved: Your form, PUNCHING MACHINE, has new responses._169.txt
# ✓ Saved: Your form, PUNCHING MACHINE, has new responses._170.txt
# ✓ Saved: Earn your degree in Computer Science from Universi_171.txt
# ✓ Saved: New courses for your new goals_172.txt
# ✓ Saved: Recommended: Google Data Analytics_173.txt
# ✓ Saved: Verify your email address_174.txt
# ✓ Saved: Get started with Microsoft Teams_175.txt
# ✓ Saved: Welcome to the McAfee family!_176.txt
# ✓ Saved: Security alert_177.txt
# ✓ Saved: Your Google data is ready to download_178.txt
# ✓ Saved: Poorna Kumar, take the next step on your Windows d_179.txt
# ✓ Saved: Get started with OneDrive_180.txt
# ✓ Saved: Get started on OneDrive for Windows_181.txt
# ✓ Saved: Welcome to Windows 11_182.txt
# ✓ Saved: Your Microsoft order #6287431968 has been processe_183.txt
# ✓ Saved: See how your identity protection service works_184.txt
# ✓ Saved: Understand how UNT will support you as a student_185.txt
# ✓ Saved: Confirm your account_186.txt
# ✓ Saved: Thanks for going with McAfee!_187.txt
# ✓ Saved: Ending soon: $200 off Coursera Plus_188.txt
# ✓ Saved: Your Google Account was recovered successfully_189.txt
# ✓ Saved: Get started with your Bachelor of Applied Arts and_190.txt
# ✓ Saved: Offer extended: $200 off Coursera Plus_191.txt
# ✓ Saved: It's Official. Order 1265331195_192.txt
# ✓ Saved: Recommended: Google UX Design_193.txt
# ✓ Saved: You're invited: BSc Computer Science's upcoming we_194.txt
# ✓ Saved: Short courses for you_195.txt
# ✓ Saved: New announcement: "ENDSEM PRACTICAL EXAMINATION
# _196.txt
# ✓ Saved: IRCTC' s Online Rail Ticket Reservation User Regis_197.txt
# ✓ Saved: IRCTC' s Online Rail Ticket Reservation User Regis_198.txt
# ✓ Saved: RE:For changing last name in my irctc profile Tick_199.txt
# ✓ Saved: RE:For changing last name in my irctc profile Tick_200.txt
# ✓ Saved: Recommended: First Step Korean_201.txt
# ✓ Saved: Protect your Windows, Mac, iOS and Android devices_202.txt
# ✓ Saved: Your Google Account was recovered successfully_203.txt
# ✓ Saved: 👋 Please confirm your email_204.txt
# ✗ Failed email b'205': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✓ Saved: Add 100 GB storage to use across your PC and devic_206.txt
# ✓ Saved: You're invited: BSc Computer Science's upcoming we_207.txt
# ✓ Saved: Offer ends soon: $200 off Coursera Plus_208.txt
# ✓ Saved: TSPSC Recruitment 2023 for Group 3 Posts begins at_209.txt
# ✓ Saved: Please confirm your email_210.txt
# ✓ Saved: Challenger_Get the most from your OneDrive_211.txt
# ✗ Failed email b'212': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Ends today! Save like never before!_213.txt
# ✓ Saved: You're invited: Bachelor of Applied Arts and Scien_214.txt
# ✓ Saved: poorna, you have a good eye_215.txt
# ✓ Saved: New sign-in detected for your Microsoft account_216.txt
# ✓ Saved: This February, take the next step for your career_217.txt
# ✓ Saved: New announcement: "Dear Students
# Kindly join wit_218.txt
# ✓ Saved: New material: "DEMO VIDEO"_219.txt
# ✓ Saved: New material: "ESTIMATION OF HARDNESS OF WATER SAM_220.txt
# ✓ Saved: New assignment: "A01"_221.txt
# ✓ Saved: New assignment: "A02 "_222.txt
# ✓ Saved: New assignment: "A04"_223.txt
# ✓ Saved: New assignment: "A03"_224.txt
# ✓ Saved: New material: "Determination of Viscosity of liqui_225.txt
# ✓ Saved: New material: "Determination of halide ion…"_226.txt
# ✓ Saved: New material: "Determination of surface tension of_227.txt
# ✓ Saved: New material: "Synthesis of Aspirin (Additional La_228.txt
# ✓ Saved: New material: "Redox titration"_229.txt
# ✓ Saved: One Time Password (OTP) for your LOGIN on IRCTC_230.txt
# ✓ Saved: Recommended: Google Data Analytics_231.txt
# ✓ Saved: poorna, you have a good eye_232.txt
# ✓ Saved: Updates to Google Play Terms of Service_233.txt
# ✓ Saved: Post Office Recruitment 2023: Registration for 40,_234.txt
# ✓ Saved: New material: "Estimation of Dichromate solution "_235.txt
# ✓ Saved: Your Google Account was recovered successfully_236.txt
# ✓ Saved: Security alert_237.txt
# ✓ Saved: New, just for you!_238.txt
# ✓ Saved: poorna, you have a good eye_239.txt
# ✗ Failed email b'240': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: New announcement: "Dear Students
# Kindly use this_241.txt
# ✓ Saved: New announcement: "Dear Students
# I am attaching t_242.txt
# ✓ Saved: New assignment: "ASSIGNMENT -1 (THEORY)"_243.txt
# ✓ Saved: New assignment: "A02"_244.txt
# ✓ Saved: New assignment: "A03"_245.txt
# ✓ Saved: New assignment: "A04"_246.txt
# ✓ Saved: Your McAfee Monthly for February_247.txt
# ✗ Failed email b'248': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Your Google Account was recovered successfully_249.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_250.txt
# ✓ Saved: Recommended: IBM Cybersecurity Analyst_251.txt
# ✓ Saved: Make Sure You're Ready for the OPSC Civil Judge Re_252.txt
# ✓ Saved: New assignment: "A04  VIRTUAL LAB -1 "_253.txt
# ✓ Saved: New assignment: "A03 - DETERMINATION OF EMF OF A C_254.txt
# ✓ Saved: New assignment: "A02 - ESTIMATION OF HARDNESS OF W_255.txt
# ✓ Saved: New assignment: "A01-DETERMINATION OF EMF OF A CEL_256.txt
# ✓ Saved: Start your career in high-growth industries with B_257.txt
# ✓ Saved: Just for you: course recommendations_258.txt
# ✓ Saved: Get started with your Bachelor of Science in Compu_259.txt
# ✓ Saved: Due tomorrow: 'A01-DETERMINATION OF EMF OF A CELL _260.txt
# ✓ Saved: Due tomorrow: 'A04 Estimation of Hardness of water_261.txt
# ✓ Saved: Due tomorrow: 'A02 ESTIMATION OF DICHROMATE'_262.txt
# ✓ Saved: Due tomorrow: 'A02 - ESTIMATION OF HARDNESS OF WAT_263.txt
# ✓ Saved: Due tomorrow: 'A03- ESTIMATION OF CHLORIDE'_264.txt
# ✓ Saved: Due tomorrow: 'A04 Estimation of Dichromate soluti_265.txt
# ✓ Saved: Due tomorrow: 'A01- ESTIMATION OF CHLORIDE ION'_266.txt
# ✓ Saved: Due tomorrow: 'A03 - DETERMINATION OF EMF OF A CEL_267.txt
# ✓ Saved: Guest edited your shared files_268.txt
# ✗ Failed email b'269': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Apply Online for 159 Technicians Posts_270.txt
# ✓ Saved: New announcement: "Dear Children..!
# Find the 211M_271.txt
# ✓ Saved: Guest edited your shared files_272.txt
# ✓ Saved: Recommended: The Science of Well-Being_273.txt
# ✓ Saved: poorna, you have a good eye_274.txt
# ✓ Saved: Apply Online Till February 26 for Fireman and Trad_275.txt
# ✓ Saved: IDBI SO Recruitment 2023 Registration Starts Today_276.txt
# ✓ Saved: Take your first step towards a sought-after techno_277.txt
# ✓ Saved: AIESL Recruitment 2023 Registration Ongoing - Vaca_278.txt
# ✓ Saved: Start a career in bookkeeping, marketing, and more_279.txt
# ✓ Saved: JNU Non-Teaching Recruitment 2023 Registration Ong_280.txt
# ✓ Saved: Anumalsetty - Virus removal comes with your subscr_281.txt
# ✓ Saved: New assignment: "A01 Determination of Hardness of _282.txt
# ✓ Saved: New assignment: "A03 Determination of Hardness of _283.txt
# ✓ Saved: New assignment: "A02 Estimation of Chloride in wat_284.txt
# ✓ Saved: New assignment: "A04 Estimation of Chloride ion in_285.txt
# ✗ Failed email b'286': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Income Tax Chandigarh Recruitment 2023 for Inspect_287.txt
# ✓ Saved: Recommended: The Science of Well-Being_288.txt
# ✓ Saved: poorna, you have a good eye_289.txt
# ✓ Saved: PSPCL Recruitment 2023: Application for 1500 Appre_290.txt
# ✓ Saved: Earn your degree in Computer Science from Universi_291.txt
# ✓ Saved: Telangana State Residential Junior College Common _292.txt
# ✗ Failed email b'293': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Subordinate Services Selection Board announced  25_294.txt
# ✓ Saved: New assignment: "A01 Generation of IR spectra with_295.txt
# ✓ Saved: New assignment: "A02 Generation of IR spectra with_296.txt
# ✓ Saved: New assignment: "A04 Generation of IR spectra with_297.txt
# ✓ Saved: New assignment: "A03 Generation of IR spectra with_298.txt
# ✓ Saved: New assignment: "A01 Experiment on surface tension_299.txt
# ✓ Saved: New assignment: "A02 Experiment on surface tension_300.txt
# ✓ Saved: New assignment: "A03 Experiment on surface tension_301.txt
# ✓ Saved: New assignment: "A04 Experiment on surface tension_302.txt
# ✓ Saved: Anumalsetty - More subscription benefits available_303.txt
# ✓ Saved: Recommended: Google Data Analytics_304.txt
# ✓ Saved: API Updates: ChatGPT, Whisper, and Developer Polic_305.txt
# ✓ Saved: poorna, these ideas are so you ❤_306.txt
# ✓ Saved: poorna, you have a good eye_307.txt
# ✓ Saved: BSc Computer Science deadline is approaching_308.txt
# ✓ Saved: Just for you: short courses_309.txt
# ✓ Saved: New assignment: "Unit 1 - ODE - Assignment"_310.txt
# ✓ Saved: New assignment: "Unit 2 - MI - Assignment"_311.txt
# ✓ Saved: Anumalsetty - More subscription benefits available_312.txt
# ✓ Saved: Your McAfee Monthly for  March_313.txt
# ✓ Saved: New material: "UNIT-2 "_314.txt
# ✓ Saved: New material: "FLUORESCENCE SPECTROSCOPY AND FOREN_315.txt
# ✓ Saved: New material: "REDOX REACTION "_316.txt
# ✗ Failed email b'317': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: GPT-4 is here _318.txt
# ✓ Saved: We found 15 ideas just for you_319.txt
# ✓ Saved: Anumalsetty - Virus removal comes with your subscr_320.txt
# ✗ Failed email b'321': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: New assignment: "Poster Presentation"_322.txt
# ✗ Failed email b'323': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Due tomorrow: 'Poster Presentation'_324.txt
# ✓ Saved: Stand out in the job market_325.txt
# ✓ Saved: We found 15 ideas just for you_326.txt
# ✓ Saved: New material: "Course plan"_327.txt
# ✓ Saved: Recommended: Deep Learning_328.txt
# ✓ Saved: poorna, these ideas are so you ❤_329.txt
# ✓ Saved: New! Immersive learning courses now on Coursera_330.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_331.txt
# ✓ Saved: poorna, these ideas are so you ❤_332.txt
# ✓ Saved: New! Advanced Certificates from Google_333.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_334.txt
# ✓ Saved: We found 17 ideas just for you_335.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_336.txt
# ✓ Saved: Your McAfee Monthly for  April_337.txt
# ✓ Saved: Be the first to explore our brand new programs_338.txt
# ✓ Saved: Welcome to GeeksforGeeks!_339.txt
# ✓ Saved: poorna, these ideas are so you ❤_340.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_341.txt
# ✓ Saved: Iphone Wallpaper for poorna 📱_342.txt
# ✓ Saved: How to get a job with no experience_343.txt
# ✓ Saved: We found 15 ideas just for you_344.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_345.txt
# ✓ Saved: Your Google Account was recovered successfully_346.txt
# ✓ Saved: Security alert_347.txt
# ✓ Saved: Security alert_348.txt
# ✓ Saved: Activate your Hoxx account_349.txt
# ✓ Saved: Hoxx reset password request_350.txt
# ✓ Saved: Hoxx reset password request_351.txt
# ✓ Saved: Marvel for poorna 🦸_352.txt
# ✓ Saved: New app(s) connected to your Microsoft account_353.txt
# ✓ Saved: Your account was tied to OpenID_354.txt
# ✓ Saved: Get started in Lucid_355.txt
# ✓ Saved: See what’s new_356.txt
# ✓ Saved: Google Verification Code_357.txt
# ✓ Saved: Google Verification Code_358.txt
# ✓ Saved: Madara Uchiha for poorna_359.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_360.txt
# ✓ Saved: Microsoft account security code_361.txt
# ✓ Saved: Microsoft account password reset_362.txt
# ✓ Saved: Microsoft account password change_363.txt
# ✓ Saved: Microsoft account security code_364.txt
# ✓ Saved: Proton Verification Code_365.txt
# ✓ Saved: Welcome to Proton VPN_366.txt
# ✓ Saved: Sending you lucky thoughts_367.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_368.txt
# ✓ Saved: Your Google Account was recovered successfully_369.txt
# ✓ Saved: NEW! Google Cybersecurity Professional Certificate_370.txt
# ✓ Saved: Trending news: Nushrratt Bharuccha on same-sex mar_371.txt
# ✓ Saved: poorna, these ideas are so you ❤_372.txt
# ✓ Saved: Flipkart Account - 978158 is your verification cod_373.txt
# ✓ Saved: New device login detected in your Flipkart account_374.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_375.txt
# ✓ Saved: Password reset link from ONPASSIVE Ecosystem_376.txt
# ✓ Saved: Build a career in Computer Science_377.txt
# ✓ Saved: poorna, you have a good eye_378.txt
# ✓ Saved: New app(s) connected to your Microsoft account_379.txt
# ✓ Saved: Courses for you_380.txt
# ✓ Saved: New app(s) connected to your Microsoft account_381.txt
# ✓ Saved: Trending news: Karnataka shows no magic needed to_382.txt
# ✓ Saved: Email verification code: 242664_383.txt
# ✓ Saved: Your email is now a recovery email for 99220040013_384.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_385.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_386.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_387.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_388.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_389.txt
# ✓ Saved: poorna, these ideas are so you ❤_390.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_391.txt
# ✓ Saved: Flipkart Account - 612762 is your verification cod_392.txt
# ✓ Saved: poorna, you have a good eye_393.txt
# ✓ Saved: Develop technical skills and sharpen your problem-_394.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_395.txt
# ✓ Saved: NEW! Google Cybersecurity Professional Certificate_396.txt
# ✗ Failed email b'397': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Your Google Account was recovered successfully_398.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_399.txt
# ✓ Saved: Your Google Account was recovered successfully_400.txt
# ✓ Saved: Security alert_401.txt
# ✓ Saved: Marvel for poorna 🦸_402.txt
# ✓ Saved: Recommended: Intuit Academy Bookkeeping_403.txt
# ✓ Saved: Share request for ‘ssᴄ ᴄᴇʀᴛɪғɪᴄᴀᴛᴇ’_404.txt
# ✗ Failed email b'405': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'406': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Madara Uchiha for poorna_407.txt
# ✓ Saved: Say hello to your reward: ₹250 Amazon Pay Gift Car_408.txt
# ✓ Saved: It’s all here, from interview tips to the science _409.txt
# ✓ Saved: Recommended: Google Data Analytics_410.txt
# ✓ Saved: Make your PC easier to use and get answers with ne_411.txt
# ✗ Failed email b'412': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Security alert for kumar173setty@gmail.com_413.txt
# ✓ Saved: Entertainment for poorna_414.txt
# ✓ Saved: redBus Ticket - TS6Z56546213_415.txt
# ✓ Saved: redBus - Tax Invoice_416.txt
# ✓ Saved: redBus Ticket - TS6Z56546213_417.txt
# ✓ Saved: Madara Uchiha for poorna_418.txt
# ✓ Saved: G, here’s everything you need for your trip to Ong_419.txt
# ✓ Saved: G Mounika, Rate your experience with redBus!_420.txt
# ✗ Failed email b'421': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Cars, Jujutsu, and more Pins popular on Pinterest _422.txt
# ✓ Saved: Trending news: Cardiologist Gaurav Gandhi, who had_423.txt
# ✓ Saved: Hi  , You're almost there.._424.txt
# ✓ Saved: Your McAfee Monthly for  June_425.txt
# ✓ Saved: Hi  , Your Cart is Missing You_426.txt
# ✓ Saved: poorna, you have a good eye_427.txt
# ✓ Saved: Google Verification Code_428.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_429.txt
# ✗ Failed email b'430': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'431': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Booking Confirmation on IRCTC, Train: 12711, 04-Ju_432.txt
# ✓ Saved: Google Calendar now shows events from Gmail_433.txt
# ✓ Saved: Booking Confirmation on IRCTC, Train: 12661, 04-Ju_434.txt
# ✓ Saved: The last slice of Pizza._435.txt
# ✗ Failed email b'436': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'437': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Your Cart misses you_438.txt
# ✓ Saved:  A Plan Dad Will Approve 😉_439.txt
# ✓ Saved: To our superhero...💪🏼👨🏻_440.txt
# ✓ Saved: poorna, these ideas are so you ❤_441.txt
# ✗ Failed email b'442': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✓ Saved: (1) Mail from Future You 🔮_443.txt
# ✓ Saved: Your Google Account was recovered successfully_444.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_445.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_446.txt
# ✓ Saved: Hey, yahaan sab hai EASYYYY!🥳_447.txt
# ✓ Saved: Inspired by poorna ❤_448.txt
# ✗ Failed email b'449': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✓ Saved: Fill in the Blanks: ___ is Wealth!_450.txt
# ✓ Saved: Introducing the NetShield Ad-blocker privacy panel_451.txt
# ✓ Saved: Fwd: Jump ahead with bonus points_452.txt
# ✓ Saved: 📌 Result Pinned _453.txt
# ✓ Saved: Hey, tick all the boxes!🤓_454.txt
# ✓ Saved: Big _____ Dhamaal!_455.txt
# ✓ Saved: Trending news: What PM Modi gifted US President Jo_456.txt
# ✓ Saved: Aadha is Not Aadhoora! 😉_457.txt
# ✗ Failed email b'458': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: poorna, you have a good eye_459.txt
# ✓ Saved: You've Scored 99_100!_460.txt
# ✓ Saved: Warning: Crazy ____ Inside!_461.txt
# ✓ Saved: All the features, free for 1 month. Go Premium._462.txt
# ✓ Saved: Chilla chilla ke scheme bata rahe hai!😎_463.txt
# ✓ Saved: iQOO account - authentication_464.txt
# ✗ Failed email b'465': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Eid Mubarak! 🌙_466.txt
# ✓ Saved: Ability Unlocked: Waterproof ✅_467.txt
# ✓ Saved: We’re updating some of our policies_468.txt
# ✓ Saved: Anumalsetty - 4 ways to prevent Phone and Chat sca_469.txt
# ✓ Saved: Trending news: Meet man who quit Rs 192 crore sala_470.txt
# ✗ Failed email b'471': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Your Weekend Plans Updated!_472.txt
# ✓ Saved:  🔍 Your Search is Complete. _473.txt
# ✓ Saved: Hey Hey, paisa vasool tickets for you! 🥳💸_474.txt
# ✓ Saved: The Eye-Conic Sale is BACK! Up to 60% off on fab s_475.txt
# ✓ Saved:  You better hurry up ⏱️_476.txt
# ✗ Failed email b'477': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✓ Saved: Fwd: Hostel fee kumar 062023_478.txt
# ✗ Failed email b'479': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Hey, we want to hear from you!_480.txt
# ✓ Saved: poorna, you have a good eye_481.txt
# ✓ Saved: Start your career in high-growth industries with B_482.txt
# ✓ Saved: We Heard Your Friends Discussing 💬_483.txt
# ✓ Saved: Keep your device safe from hackers._484.txt
# ✗ Failed email b'485': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Drive positive change with AI_486.txt
# ✓ Saved: Challenge: Can you unlock this?👇🔒_487.txt
# ✓ Saved: Hang your Feet & look at these! 😲_488.txt
# ✓ Saved: Updates to _489.txt
# ✓ Saved: This one's for the Super-Woman! 👩 ⚡️_490.txt
# ✓ Saved: Anumalsetty - Save 70% on your renewal this week o_491.txt
# ✗ Failed email b'492': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Security alert for 99220040013@klu.ac.in_493.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_494.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_495.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_496.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_497.txt
# ✗ Failed email b'498': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Safety measures you need to know about_499.txt
# ✓ Saved: Invitation: Come, Cook with Us?_500.txt
# ✗ Failed email b'501': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Anumalsetty - Only 4 days left to save 70% on your_502.txt
# ✓ Saved: Your Fav Premium Brands are here 👀_503.txt
# ✓ Saved: Take your first step towards a sought-after techno_504.txt
# ✓ Saved: Get ready for your next trip with these 6 tips_505.txt
# ✓ Saved: Decode: 🎁 opens and you go 😳 _506.txt
# ✓ Saved: Spotify Premium for free, click or _507.txt
# ✗ Failed email b'508': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Look what's raining here! ☔️😱_509.txt
# ✓ Saved: Sshh! 🤫 This must stay between us!_510.txt
# ✓ Saved: Trending news: Meet Delhi's richest man with Rs 2._511.txt
# ✓ Saved: Open for Instant Happiness 😃 💫_512.txt
# ✓ Saved: VC Sleek Steel: Elevate Your Style with the Perfec_513.txt
# ✓ Saved: Anumalsetty - Last chance! Save 70% on your renewa_514.txt
# ✓ Saved: (1) Secret Message Inside_515.txt
# ✓ Saved: Your dream journey is here 😍_516.txt
# ✓ Saved: Oops. Sorry! We just dropped these..._517.txt
# ✓ Saved: You have to see this to believe it... 👀_518.txt
# ✓ Saved: Join Xbox Game Pass Ultimate now and stop our exti_519.txt
# ✓ Saved: Friends, we love & hate to tell you this..._520.txt
# ✗ Failed email b'521': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: You have ONLY one day.._522.txt
# ✓ Saved: Hello  .. you left something in your cart!_523.txt
# ✓ Saved: 🎬Free Ticket for You Inside .._524.txt
# ✓ Saved: GFG, Now In Your Pockets! 📲_525.txt
# ✓ Saved: Bach ke rehna re baba...☔️_526.txt
# ✗ Failed email b'527': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'528': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✓ Saved: New device login detected in your Flipkart account_529.txt
# ✓ Saved: Tell us about your Search & Selection experience o_530.txt
# ✗ Failed email b'531': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: 10 Things You Need._532.txt
# ✓ Saved: New sign-in detected for your Microsoft account_533.txt
# ✓ Saved: Security alert_534.txt
# ✓ Saved: Your Google Account was recovered successfully_535.txt
# ✓ Saved: Your Google Account was recovered successfully_536.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_537.txt
# ✓ Saved: This will make your Monday better. Promise!_538.txt
# ✗ Failed email b'539': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: POORNA173, join Xbox Game Pass Ultimate for Rs. 50_540.txt
# ✓ Saved: Anumalsetty, Action required!_541.txt
# ✓ Saved: NOW SERVING: Jawdrops 😱👀_542.txt
# ✓ Saved: Microsoft account security info was added_543.txt
# ✗ Failed email b'544': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✓ Saved: Tips to use your PC for home entertainment._545.txt
# ✓ Saved: Hey, this is important!😨_546.txt
# ✓ Saved: Unbox Early Weekend 😉_547.txt
# ✗ Failed email b'548': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'549': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: PC games ready to play_550.txt
# ✗ Failed email b'551': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Security alert_552.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_553.txt
# ✗ Failed email b'554': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Question: What's 🔥 Than 🌶️?_555.txt
# ✓ Saved: Hey, don't miss out on this!_556.txt
# ✗ Failed email b'557': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Hey, you've got to hurry!😱_558.txt
# ✓ Saved: Trending news: Venezuela model Ariana Viera dies a_559.txt
# ✓ Saved: Decode: 😎 + 🥶 + 🛍 = ??_560.txt
# ✓ Saved: Updating our Google Account inactivity policy_561.txt
# ✓ Saved: Discover Affordable Luxury: 10 Premium Picks You C_562.txt
# ✗ Failed email b'563': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Dekho...long weekend bas aa gaya!😍_564.txt
# ✓ Saved: Hey, the revolution has started! 🇮🇳 🚌_565.txt
# ✓ Saved: Security alert_566.txt
# ✓ Saved: Welcome to IMDb!_567.txt
# ✓ Saved: ✅ Poorna Kumar, finish setting up your Realme C15 _568.txt
# ✓ Saved: OTP_569.txt
# ✓ Saved: Your request for Reprint of Pan card submitted vid_570.txt
# ✓ Saved: The Nation Wants... _571.txt
# ✓ Saved: New app(s) connected to your Microsoft account_572.txt
# ✓ Saved: POORNA173, gamescom is coming - don’t miss Xbox’s _573.txt
# ✓ Saved: Mission Start Time: Now_574.txt
# ✓ Saved: Don't miss this mail!😱_575.txt
# ✓ Saved: ❤ poorna, these ideas are so you_576.txt
# ✓ Saved: Welcome to IMDb!_577.txt
# ✓ Saved: Reminder: You've one pending message from 🚀 _578.txt
# ✓ Saved: Hey, last chance to grab this offer!🤩_579.txt
# ✓ Saved: poorna, you have a good eye_580.txt
# ✓ Saved: Your McAfee Monthly for Aug_581.txt
# ✓ Saved: 📱 Wallpaper for poorna_582.txt
# ✗ Failed email b'583': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: 'Barbie' joins the billion-dollar film club_584.txt
# ✓ Saved: We bet you didn't know this!😏_585.txt
# ✗ Failed email b'586': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: The best things to watch in August_587.txt
# ✗ Failed email b'588': [Errno 22] Invalid argument: "c:\\Users\\aspk1\\On...
# ✗ Failed email b'589': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Hey Hey, here’s how you can make a difference! 🫡_590.txt
# ✓ Saved: 5 new releases to watch this week_591.txt
# ✓ Saved: Made in India 🧡🤍💚_592.txt
# ✓ Saved: Celebrating the spirit of 🇮🇳India!_593.txt
# ✓ Saved: G Mounika, Happy Independence Day!_594.txt
# ✓ Saved: 📱 Disney Wallpaper for poorna_595.txt
# ✓ Saved: LANDING in...3...2...1!_596.txt
# ✓ Saved: poorna, you have a good eye_597.txt
# ✗ Failed email b'598': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: POORNA173, QuakeCon 2023 has the latest on Quake I_599.txt
# ✓ Saved:   🛜  Wifi Password: Savings _600.txt
# ✓ Saved: Meet 'Blue Beetle' star Xolo Maridueña_601.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_602.txt
# ✓ Saved: 3 free months of Premium: Find your mood_603.txt
# ✗ Failed email b'604': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'605': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: POORNA173, don’t forget – Xbox’s broadcast from ga_606.txt
# ✓ Saved: Trending news: Chandrayaan-3 lander prepares for_607.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_608.txt
# ✓ Saved: It's our birthday today!🥳_609.txt
# ✓ Saved: 📸 Picture the Possibilities: Unleash Your Creativi_610.txt
# ✓ Saved: Theatrical releases you can now stream or rent_611.txt
# ✓ Saved: 5+ tips for staying productive on your Windows PC._612.txt
# ✓ Saved: Upgrade your eyewear game with Matte Essentials_613.txt
# ✗ Failed email b'614': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: G Mounika, an offer you can't refuse!_615.txt
# ✓ Saved: Personalized playlist recommendations, curated jus_616.txt
# ✓ Saved: 🎁 Gift Box Delivery Waiting..._617.txt
# ✓ Saved: G Mounika, let us know what you think of sustainab_618.txt
# ✓ Saved: 5 things you need to watch this week_619.txt
# ✗ Failed email b'620': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Order complete! Start learning now._621.txt
# ✓ Saved: New message from Anton Voroniuk on Udemy_622.txt
# ✓ Saved: Welcome to Udemy, Poorna kumar Anumala!_623.txt
# ✗ Failed email b'624': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: G Mounika, yeh hai sacha pyaar!🤩_625.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_626.txt
# ✓ Saved: 🔪 Introducing Wednesday Price Slice: Grab the Fres_627.txt
# ✓ Saved: New Arrival Alert: Meet our captivating Jade Green_628.txt
# ✓ Saved: Join Xbox Game Pass Ultimate and pre-install this _629.txt
# ✓ Saved: 3 months of Premium, free: Keep flowing_630.txt
# ✓ Saved: Play Age of Empires IV: Anniversary Edition now on_631.txt
# ✓ Saved: 🇮🇳 India's on (& over) the moon!_632.txt
# ✓ Saved: 🟡Peak_633.txt
# ✗ Failed email b'634': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: POORNA173, pre-order Starfield Premium Edition now_635.txt
# ✓ Saved: Get one up on AI during our biggest sale of the se_636.txt
# ✓ Saved: Trending news: NYT's Elite Space Club in awe &_637.txt
# ✓ Saved: Invitation: a Game for Riddle Fans 🧩
# _638.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_639.txt
# ✓ Saved: Ready. Steady. Aim 🎯🎯🎯🎯_640.txt
# ✓ Saved: Is it really a Rakhi _641.txt
# ✓ Saved: Security alert_642.txt
# ✓ Saved: Your Account is in Safe Mode_643.txt
# ✓ Saved: WOOF WOOF 🐶 Open for Translation 👇🏼_644.txt
# ✓ Saved: Brand new book-to-screen adaptations_645.txt
# ✗ Failed email b'646': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: New message from Anton Voroniuk on Udemy_647.txt
# ✓ Saved: 🎨 Art, DIY and Home Improvement, and more Pins pop_648.txt
# ✓ Saved: Order complete! Start learning now._649.txt
# ✓ Saved: New message from Horizon Tech on Udemy_650.txt
# ✓ Saved: Order complete! Start learning now._651.txt
# ✓ Saved: New message from Krish valley on Udemy_652.txt
# ✓ Saved: Welcome to Bard_653.txt
# ✓ Saved: Celebrate Rakhi with Stylish Eyewear + Exclusive S_654.txt
# ✓ Saved: Signal Green 🚦_655.txt
# ✓ Saved: With courses from _656.txt
# ✓ Saved: 5 top-rated Will Ferrell movies streaming right no_657.txt
# ✓ Saved: Order complete! Start learning now._658.txt
# ✓ Saved: New message from Web Oral on Udemy_659.txt
# ✓ Saved: Order complete! Start learning now._660.txt
# ✓ Saved: New message from Web Oral on Udemy_661.txt
# ✓ Saved: India Deserves Gold 🏅 And You... _662.txt
# ✗ Failed email b'663': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: POORNA173, experience all the excitement from game_664.txt
# ✓ Saved: POORNA173, join Xbox Game Pass Ultimate now and ge_665.txt
# ✓ Saved: 140192 is your OTP for Email Verification_666.txt
# ✓ Saved: Set up your personal account_667.txt
# ✓ Saved: Welcome to our official newsletter_668.txt
# ✗ Failed email b'669': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Order complete! Start learning now._670.txt
# ✓ Saved: New message from Natsuko Yunome on Udemy_671.txt
# ✓ Saved: Order complete! Start learning now._672.txt
# ✓ Saved: New message from Web Oral on Udemy_673.txt
# ✗ Failed email b'674': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Ending today: Our biggest sale of the season_675.txt
# ✓ Saved: Everything we know about Zack Snyder's 'Rebel Moon_676.txt
# ✓ Saved: 🌟 August's Bestsellers: Hot Products You Can't Mis_677.txt
# ✓ Saved: Upgrade your eyewear game with Matte Essentials_678.txt
# ✓ Saved: Updates to our terms of use_679.txt
# ✗ Failed email b'680': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Phone Wallpaper, Phone Background, and more Pins p_681.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_682.txt
# ✗ Failed email b'683': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Celebration begins in 3..2..1... 🎉_684.txt
# ✓ Saved: 💜_685.txt
# ✓ Saved: Don't miss 3 free months of Premium_686.txt
# ✓ Saved: Subscribe to success with Personal Plan_687.txt
# ✗ Failed email b'688': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: See what's streaming in September_689.txt
# ✗ Failed email b'690': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'691': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Time Left: ☝️ Day!
# _692.txt
# ✓ Saved: G Mounika, yeh hai sacha pyaar!🤩_693.txt
# ✓ Saved: Still interested in _694.txt
# ✓ Saved: Bing homepage quiz_695.txt
# ✗ Failed email b'696': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: 5 things to watch this week_697.txt
# ✓ Saved: 🤖_698.txt
# ✓ Saved: This is how you become a lifelong learner_699.txt
# ✓ Saved: New courses, new possibilities_700.txt
# ✓ Saved: We love you! 😍_701.txt
# ✓ Saved: Your Class is Starting Now 👩‍🏫‍_702.txt
# ✓ Saved: We love you! 😍_703.txt
# ✓ Saved: G Mounika, we want to hear from you!_704.txt
# ✓ Saved: inhorizontech@gmail.com_705.txt
# ✓ Saved: poorna, you have a good eye_706.txt
# ✓ Saved: 🇮🇳 Introducing the Elite 8: Top Brands Making Indi_707.txt
# ✓ Saved: Bing homepage quiz_708.txt
# ✗ Failed email b'709': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'710': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: POORNA173, get ready for lift off now with Starfie_711.txt
# ✓ Saved: Your fall TV guide is here_712.txt
# ✓ Saved: Final days: 3 free months of Premium_713.txt
# ✓ Saved: Sale ends today! Courses as low as _714.txt
# ✓ Saved: POORNA173, join Xbox Game Pass Ultimate today and _715.txt
# ✗ Failed email b'716': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: You weekend starts HERE_717.txt
# ✓ Saved: G Mounika, we want to hear from you!_718.txt
# ✓ Saved: You’ve_719.txt
# ✓ Saved: 📱 Disney Wallpaper for poorna_720.txt
# ✓ Saved: Your features, don’t forget to use them _721.txt
# ✓ Saved: Ganpati Bappa Arriving Soon 😇🙏_722.txt
# ✓ Saved: Rock the K-Pop look in style 🌟_723.txt
# ✓ Saved: Poorna kumar Anumala, try our free learning course_724.txt
# ✓ Saved: oceansvalley@gmail.com_725.txt
# ✓ Saved: This feature on our app is 🤩_726.txt
# ✓ Saved: Look Upppp 👆No, Higher!_727.txt
# ✓ Saved: Bing homepage quiz_728.txt
# ✓ Saved: 3 questions to help you start learning again _729.txt
# ✓ Saved: 🚨 Calling all Bloggers 😎_730.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_731.txt
# ✓ Saved: We’ve_732.txt
# ✓ Saved: All-star courses for your next win_733.txt
# ✓ Saved: CAUTION: Your Jaw May Hit the Keyboard_734.txt
# ✓ Saved: The 5 top-rated TV pilots on IMDb_735.txt
# ✓ Saved: Here’s_736.txt
# ✓ Saved: ⏰_737.txt
# ✓ Saved: The ultimate road trip playlist! 🤩_738.txt
# ✗ Failed email b'739': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: 🎁Celebrate_740.txt
# ✓ Saved: Bing homepage quiz_741.txt
# ✓ Saved: Security alert_742.txt
# ✓ Saved: Our sale ends today! Shop now to get courses on sa_743.txt
# ✓ Saved: ❤ poorna, these ideas are so you_744.txt
# ✗ Failed email b'745': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Bolo..क , ख , ग, घ....😎_746.txt
# ✓ Saved: Still interested in _747.txt
# ✗ Failed email b'748': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Rock the K-Pop look in style 🌟_749.txt
# ✓ Saved: Get ready to reach your next goal_750.txt
# ✓ Saved: 📱 Wallpaper for poorna_751.txt
# ✓ Saved: Your Fortune for the Day 👇🏼_752.txt
# ✓ Saved: The most anticipated fall festival films & series_753.txt
# ✓ Saved: A new course for you based on Programming Language_754.txt
# ✓ Saved: See, hundred percent you'll not get.._755.txt
# ✗ Failed email b'756': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: 'A Haunting in Venice' stars through the years_757.txt
# ✓ Saved: Bing homepage quiz_758.txt
# ✓ Saved: Poorna kumar Anumala, check out your latest batch _759.txt
# ✓ Saved: POV : Adulting is hard..🙄_760.txt
# ✓ Saved: Today only! Courses start at _761.txt
# ✓ Saved: 5 premieres to watch this week_762.txt
# ✓ Saved: Ganesh-ji is here with blessings & lots of gifts!_763.txt
# ✓ Saved: G Mounika, Happy Ganesh Chaturthi!_764.txt
# ✓ Saved: Meet the new Bard model, extensions, and more_765.txt
# ✗ Failed email b'766': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Security alert for 99220040013@klu.ac.in_767.txt
# ✓ Saved: Security alert for 99220040013@klu.ac.in_768.txt
# ✓ Saved: 🚀Level_769.txt
# ✓ Saved: Bunch of matches that Seema Aunty approves!_770.txt
# ✓ Saved: How to Find Time for Learning: Tips for Busy Peopl_771.txt
# ✓ Saved: Bing homepage quiz_772.txt
# ✓ Saved: Poorna kumar Anumala, here are some tips for learn_773.txt
# ✓ Saved: ⚽ Sport for poorna_774.txt
# ✓ Saved: The right courses _775.txt
# ✓ Saved: 👽Aliens are trying to contact you.._776.txt
# ✓ Saved: All the reasons to love Ncuti Gatwa_777.txt
# ✓ Saved: Long weekend coming up!🙌_778.txt
# ✓ Saved: It's the last day to get courses from _779.txt
# ✓ Saved: Trending news: Types of friendships we should stay_780.txt
# ✓ Saved: Mr. Bachchan has a question for you 💬_781.txt
# ✓ Saved: The latest releases you can stream or rent_782.txt
# ✗ Failed email b'783': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Learning can help you get where you want to be_784.txt
# ✓ Saved: This is the Future of Brands 😎_785.txt
# ✗ Failed email b'786': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Bing homepage quiz_787.txt
# ✓ Saved: Find out if that course is right for you._788.txt
# ✓ Saved: inhorizontech@gmail.com_789.txt
# ✓ Saved: oceansvalley@gmail.com_790.txt
# ✓ Saved: Sale: Courses from _791.txt
# ✓ Saved: Leaked! Chat between Flipkart Employees_792.txt
# ✓ Saved: 5 fan-favorite manga adaptations_793.txt
# ✓ Saved: 📱 Disney Wallpaper for poorna_794.txt
# ✓ Saved: This email has chosen youyouyouyouyouyouyouyou_795.txt
# ✓ Saved: Your Marksheet: 99_100  ✅_796.txt
# ✓ Saved: G Mounika, thoda jaldi karo‼️_797.txt
# ✓ Saved: 🚨 Alert: Rules have been Broken._798.txt
# ✓ Saved: Bing homepage quiz_799.txt
# ✓ Saved: POORNA173, join Xbox Game Pass Ultimate today and _800.txt
# ✓ Saved: Last day to save! Courses from _801.txt
# ✓ Saved: G Mounika, long weekend aur suhana safar. Chalo ch_802.txt
# ✗ Failed email b'803': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'804': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Security alert for 99220040013@klu.ac.in_805.txt
# ✓ Saved: 🗓️The Dates ARE (finally) Out!_806.txt
# ✓ Saved: Get personalised AI experiences from Windows_807.txt
# ✓ Saved: Poorna kumar Anumala, check out your latest batch _808.txt
# ✓ Saved: Weekend Game Zone Pass! 🎟️_809.txt
# ✓ Saved: Get Dhaakad deals this week!_810.txt
# ✓ Saved: Notification: Salary Credited. 💵_811.txt
# ✓ Saved: poorna, you have a good eye_812.txt
# ✓ Saved: G Mounika, ticket toh book karo dost! 🤓_813.txt
# ✓ Saved: Bing homepage quiz_814.txt
# ✗ Failed email b'815': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: 5 things to watch this week_816.txt
# ✓ Saved: This season just got Hotter! 🥵_817.txt
# ✓ Saved: G Mounika, Happy Gandhi Jayanti!_818.txt
# ✓ Saved: See what's streaming in October_819.txt
# ✗ Failed email b'820': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Courses on sale from _821.txt
# ✓ Saved: 🍎_822.txt
# ✓ Saved: Take in all the top highlights from Tokyo Game Sho_823.txt
# ✓ Saved: Bing homepage quiz_824.txt
# ✓ Saved: Sale from _825.txt
# ✓ Saved: Our favorite film & TV quarterbacks_826.txt
# ✓ Saved: G Mounika, Allu Arjun is back!😍_827.txt
# ✗ Failed email b'828': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: inhorizontech@gmail.com_829.txt
# ✗ Failed email b'830': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Join Ultimate now to play upcoming games featured _831.txt
# ✓ Saved: A menu 🍕 curated for You!_832.txt
# ✓ Saved: ❤ poorna, these ideas are so you_833.txt
# ✓ Saved: The best things premiering in October_834.txt
# ✓ Saved: Weekend Delight: 🛍️ today, 💰 later!_835.txt
# ✓ Saved: Don't open this email at night 👀_836.txt
# ✓ Saved: New device login detected in your Flipkart account_837.txt
# ✓ Saved: Your Order for AJRO DEAL Climbing Fin... has been _838.txt
# ✓ Saved: We won't tell anyone..._839.txt
# ✓ Saved: Bing homepage quiz_840.txt
# ✓ Saved: G Mounika, Allu Arjun has a message for you!😎_841.txt
# ✗ Failed email b'842': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: 5 Halloween movies kids will love_843.txt
# ...
# ✓ Saved: Sent ₹ 292 to  ANANDHAM XEROX _1459.txt
# ✓ Saved: Sent ₹ 145 to  RAJNARAYANAN _1460.txt
# ✓ Saved: Sent ₹ 100 to  RAJNARAYANAN _1461.txt
# ✓ Saved: inhorizontech@gmail.com_1462.txt
# ✓ Saved: Don't miss 3 months of Spotify Premium for _1463.txt
# ✓ Saved: Sent ₹ 82 to  VIKKURTHI  SUJATHA _1464.txt
# ✓ Saved: properdotinstitute@gmail.com_1465.txt
# ✓ Saved: Don't miss 3 months of Spotify Premium for _1466.txt
# ✓ Saved: 🎄This_1467.txt
# ✓ Saved: Unlock holiday savings & stress-free shopping with_1468.txt
# ✓ Saved: oceansvalley@gmail.com_1469.txt
# ✓ Saved: Sent ₹ 2000 to  ARMUGAM  BHASKAR _1470.txt
# ✓ Saved: Sent ₹ 55 to  BALASUBRAMANIAM A _1471.txt
# ✓ Saved: Sent ₹ 55 to  THUMULURI HARSHA SRI  KARTHIKEYA _1472.txt
# ✓ Saved: Payment for BSNL Mobile of ₹ 109 is successful_1473.txt
# ✓ Saved: Sent ₹ 210 to  NALABAGAM CANTEEN _1474.txt
# ✓ Saved: LAST YEAREND SALE - BUY 1 GET 8 COURSE_1475.txt
# ✓ Saved: Sent ₹ 18 to  NAYAKIS FOODS _1476.txt
# ✓ Saved: Sent ₹ 100 to  BUCHIRAJU SAI KIRAN _1477.txt
# ✓ Saved: Sent ₹ 130 to  Abburi  Manohar _1478.txt
# ✓ Saved: Sent ₹ 100 to  VIKKURTHI  SUJATHA _1479.txt
# ✓ Saved: Sent ₹ 36 to  NAYAKIS FOODS _1480.txt
# ✓ Saved: Payment for Jio Mobile of ₹ 902 is successful_1481.txt
# ✓ Saved: inhorizontech@gmail.com_1482.txt
# ✓ Saved: Sent ₹ 18 to  NAYAKIS FOODS _1483.txt
# ✓ Saved: Sent ₹ 96 to  VIKKURTHI  SUJATHA _1484.txt
# ✓ Saved: 💎Skills pay the Bills—not_1485.txt
# ✓ Saved: properdotinstitute@gmail.com_1486.txt
# ✓ Saved: Sent ₹ 18 to  NAYAKIS FOODS _1487.txt
# ✓ Saved: 🎥How_1488.txt
# ✓ Saved: Sent ₹ 4000 to  VIKKURTHI  SUJATHA _1489.txt
# ✓ Saved: oceansvalley@gmail.com_1490.txt
# ✓ Saved: Google Verification Code_1491.txt
# ✓ Saved: Your Google Account was recovered successfully_1492.txt
# ✓ Saved: Security alert for kumarpurna057@gmail.com_1493.txt
# ✓ Saved: Security alert for kumarpurna057@gmail.com_1494.txt
# ✓ Saved: Sent ₹ 500 to  Gongati Lakshmi Rupanjali _1495.txt
# ✓ Saved: Sent ₹ 210 to  PEDDI NAGARAJA _1496.txt
# ✓ Saved: Sent ₹ 1250 to  V CELLULOID Satyanarayana Kalamand_1497.txt
# ✓ Saved: Sent ₹ 450 to  KATTA KAJESWARA RAO _1498.txt
# ✓ Saved: ⏰_1499.txt
# ✓ Saved: Sent ₹ 500 to  KOMMANABOINA         _1500.txt
# ✓ Saved: NEWYEAR SALE - BUY 1 GET 8 COURSE_1501.txt
# ✓ Saved: Cancel Ticket_1502.txt
# ✓ Saved: Sent ₹ 140 to  MATCHA GOPAL REDDY _1503.txt
# ✓ Saved: Sent ₹ 123.88 to  Burger King India _1504.txt
# ✓ Saved: properdotinstitute@gmail.com_1505.txt
# ✓ Saved: Sent ₹ 62 to  NAYAKIS FOODS _1506.txt
# ✓ Saved: Sent ₹ 325 to  KOSURI SATYA DEEVEN _1507.txt
# ✓ Saved: 💥_1508.txt
# ✓ Saved: oceansvalley@gmail.com_1509.txt
# ✓ Saved: Sent ₹ 125 to  BALASUBRAMANIAM A _1510.txt
# ✓ Saved: Sent ₹ 60 to  RAJNARAYANAN _1511.txt
# ✓ Saved: Sent ₹ 180 to  VIKKURTHI  SUJATHA _1512.txt
# ✓ Saved: 🚀_1513.txt
# ✓ Saved: 2nd International Conference on Computing and Mach_1514.txt
# ✓ Saved: inhorizontech@gmail.com_1515.txt
# ✓ Saved: Sent ₹ 72 to  VIKKURTHI  SUJATHA _1516.txt
# ✓ Saved: Sent ₹ 200 to  VIKKURTHI  SUJATHA _1517.txt
# ✓ Saved: Sent ₹ 200 to  KATTA KAJESWARA RAO _1518.txt
# ✓ Saved: Security alert for kumarpurna057@gmail.com_1519.txt
# ✓ Saved: MS OFFICE MASTERCLASS BUY 1 GET 3 COURSE_1520.txt
# ✓ Saved: 2nd International Conference on Business Intellige_1521.txt
# ✓ Saved: 🤯 The #1 App That’s_1522.txt
# ✓ Saved: Sent ₹ 112 to  S RAMKUMAR _1523.txt
# ✓ Saved: 2nd International Conference on Business Intellige_1524.txt
# ✓ Saved: You’re_1525.txt
# ✗ Failed email b'1526': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'1527': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Fwd: Decision on Your Submission Paper ID "552" to_1528.txt
# ✓ Saved: Sent ₹ 60 to  VIKKURTHI  SUJATHA _1529.txt
# ✓ Saved: ICEARS 2025 - Acceptance Letter_1530.txt
# ✓ Saved: 🎉 800K Students Can’t_1531.txt
# ✓ Saved: Re: ICEARS 2025 - Acceptance Letter_1532.txt
# ✓ Saved: Re: ICEARS 2025 - Acceptance Letter_1533.txt
# ✓ Saved: Sent ₹ 30 to  Pandiselvi Store _1534.txt
# ✓ Saved: Sent ₹ 10 to  Pandiselvi Store _1535.txt
# ✓ Saved: Sent ₹ 1300 to  VIKKURTHI  SUJATHA _1536.txt
# ✓ Saved: Crunchcoding.com oceansvalley@gmail.com_1537.txt
# ✓ Saved: inhorizontech@gmail.com_1538.txt
# ✓ Saved: Crunchcoding.com oceansvalley@gmail.com_1539.txt
# ✓ Saved: 6th International conference on Recent Trends in M_1540.txt
# ✓ Saved: 6th International conference on Recent Trends in M_1541.txt
# ✓ Saved: Sent ₹ 100 to  GOKULAVANI  K _1542.txt
# ✓ Saved: properdotinstitute@gmail.com_1543.txt
# ✓ Saved: Crunchcoding.com oceansvalley@gmail.com_1544.txt
# ✓ Saved: Sent ₹ 15 to  Pandiselvi Store _1545.txt
# ✗ Failed email b'1546': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Sent ₹ 340 to  Indian Railways _1547.txt
# ✓ Saved: Sent ₹ 500 to  Mrs THANIKONDA  KOTESWARAMMA _1548.txt
# ✓ Saved: VALENTINE COURSE - BUY 1 GET 8 COURSE_1549.txt
# ✓ Saved: BIDA 2025 Notification for Paper ID 394_1550.txt
# ✓ Saved: BIDA 2025 Notification for Paper ID 382_1551.txt
# ✓ Saved: AI is Replacing _1552.txt
# ✓ Saved: 🥳 SkillsBooster Turns 4—And_1553.txt
# ✓ Saved: CML 2025 Notification for Paper ID 868_1554.txt
# ✓ Saved: oceansvalley@gmail.com_1555.txt
# ✓ Saved: FIRST NATIONAL LEVEL RESEARCH CONCLAVE : Submissio_1556.txt
# ✓ Saved: Notification of Your Paper ID 448 for Presentation_1557.txt
# ✓ Saved: Notification of Your Paper ID 447 for Presentation_1558.txt
# ✓ Saved: inhorizontech@gmail.com_1559.txt
# ✓ Saved: Fifth IEEE International Conference on Computing a_1560.txt
# ✓ Saved: Heartfelt Thanks to All Authors and Reviewers _1561.txt
# ✓ Saved: oceansvalley@gmail.com_1562.txt
# ✓ Saved: Call for Papers: 2nd International Conference on A_1563.txt
# ✓ Saved: Sent ₹ 1000 to  Gongati Lakshmi Rupanjali _1564.txt
# ✓ Saved: LEARN WEB DEVELOPMNET, UIUX, MS OFFICE WITH 80% OF_1565.txt
# ✓ Saved: Security alert for kumarpurna057@gmail.com_1566.txt
# ✓ Saved: Security alert for kumarpurna057@gmail.com_1567.txt
# ✓ Saved: IEEE 4th International Conference on Advances in C_1568.txt
# ✓ Saved: properdotinstitute@gmail.com_1569.txt
# ✓ Saved: Crunchcoding.com oceansvalley@gmail.com_1570.txt
# ✓ Saved: Check out Leetcode 42 _1571.txt
# ✓ Saved: 2nd IEEE International Conference on Data Science _1572.txt
# ✓ Saved: 2025 IEEE International conference on Research Met_1573.txt
# ✓ Saved: 3rd IEEE International Conference on Computer, Ele_1574.txt
# ✓ Saved: 3rd IEEE International Conference on Computer, Ele_1575.txt
# ✓ Saved: IEEE Guwahati Subsection Conference 2025 : Submiss_1576.txt
# ✓ Saved: IEEE 5th International Conference on Sustainable E_1577.txt
# ✓ Saved: IEEE 5th International Conference on Sustainable E_1578.txt
# ✓ Saved: IEEE North-East India International Energy Convers_1579.txt
# ✓ Saved: IEEE North-East India International Energy Convers_1580.txt
# ✓ Saved: 😱You’re_1581.txt
# ✗ Failed email b'1582': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: Sent ₹ 260 to  VIKKURTHI  SUJATHA _1583.txt
# ✓ Saved: Payment for BSNL Mobile of ₹ 149 is successful_1584.txt
# ✓ Saved: Subject: RMKMATE2025  Submission Confirmation  _1585.txt
# ✓ Saved: ♥️_1586.txt
# ✓ Saved: Sent ₹ 100 to  KALASALINGAM UNIVERSITY _1587.txt
# ✓ Saved: Confirmation instructions_1588.txt
# ✓ Saved: Security alert_1589.txt
# ✓ Saved: inhorizontech@gmail.com_1590.txt
# ✓ Saved: IEEE GCON2025_1591.txt
# ✓ Saved: Sent ₹ 90 to  GOKA SRIKANTH _1592.txt
# ✓ Saved: properdotinstitute@gmail.com_1593.txt
# ✓ Saved: Breaking down Hard Leetcode Question and Make it e_1594.txt
# ✓ Saved: Udemy Login: Here's the 6-digit verification code _1595.txt
# ✓ Saved: New message from PROPER DOT INSTITUTE on Udemy_1596.txt
# ✓ Saved: oceansvalley@gmail.com_1597.txt
# ✓ Saved: Crunchcoding.com oceansvalley@gmail.com_1598.txt
# ✓ Saved: Udemy Login: Here's the 6-digit verification code _1599.txt
# ✓ Saved: Order complete! Start learning now._1600.txt
# ✓ Saved: Order complete! Start learning now._1601.txt
# ✓ Saved: New message from Mohammed Asif Khan on Udemy_1602.txt
# ✓ Saved: Order complete! Start learning now._1603.txt
# ✓ Saved: New message from Mehmood Khalil on Udemy_1604.txt
# ✓ Saved: Order complete! Start learning now._1605.txt
# ✓ Saved: New message from Crunch Coding on Udemy_1606.txt
# ✓ Saved: Order complete! Start learning now._1607.txt
# ✓ Saved: Order complete! Start learning now._1608.txt
# ✓ Saved: New message from Horizon Tech on Udemy_1609.txt
# ✓ Saved: New message from Ram Din on Udemy_1610.txt
# ✓ Saved: Order complete! Start learning now._1611.txt
# ✓ Saved: New message from Joshan Grewal on Udemy_1612.txt
# ✓ Saved: Order complete! Start learning now._1613.txt
# ✓ Saved: New message from Nick Ovchinnikov on Udemy_1614.txt
# ✓ Saved: Order complete! Start learning now._1615.txt
# ✓ Saved: New message from Tech Blazes on Udemy_1616.txt
# ✓ Saved: Order complete! Start learning now._1617.txt
# ✓ Saved: New message from Tech Blazes on Udemy_1618.txt
# ✓ Saved: Order complete! Start learning now._1619.txt
# ✓ Saved: New message from PROPER DOT INSTITUTE on Udemy_1620.txt
# ✓ Saved: Order complete! Start learning now._1621.txt
# ✓ Saved: New message from TJ Walker on Udemy_1622.txt
# ✓ Saved: 🏆97%_1623.txt
# ✓ Saved: 🏆97%_1624.txt
# ✓ Saved: Live Office Hours with TJ - March 13, 10:00 AM EST_1625.txt
# ✓ Saved: Sent ₹ 150 to  VIKKURTHI  SUJATHA _1626.txt
# ✓ Saved: AI Agents Are Changing _1627.txt
# ✓ Saved: CML 2025: Conference Program Schedule_1628.txt
# ✓ Saved: 😳Most People Stop Here…_1629.txt
# ✓ Saved: Matrix Multiplication and Linear Layers in MicroTo_1630.txt
# ✓ Saved: oceansvalley@gmail.com_1631.txt
# ✓ Saved: Sent ₹ 100 to  KAJA NAGA VENKATA SAI ROOP ABIJITH _1632.txt
# ✓ Saved: Crush Tricky Binary Search Problem - Leetcode 875 _1633.txt
# ✓ Saved: properdotinstitute@gmail.com_1634.txt
# ✓ Saved: BUY 1 GET 8 COURSE LIMITED TIME OFFER_1635.txt
# ✓ Saved: Order complete! Start learning now._1636.txt
# ✓ Saved: New message from Vijay Kumar on Udemy_1637.txt
# ✓ Saved: Order complete! Start learning now._1638.txt
# ✓ Saved: New message from Vijay Kumar on Udemy_1639.txt
# ✓ Saved: New message from Vijay Kumar on Udemy_1640.txt
# ✓ Saved: Order complete! Start learning now._1641.txt
# ✓ Saved: Order complete! Start learning now._1642.txt
# ✓ Saved: New message from Vijay Kumar on Udemy_1643.txt
# ✓ Saved: Order complete! Start learning now._1644.txt
# ✓ Saved: New message from Vijay Kumar on Udemy_1645.txt
# ✓ Saved: Order complete! Start learning now._1646.txt
# ✓ Saved: Order complete! Start learning now._1647.txt
# ✓ Saved: New message from Andrii Piatakha on Udemy_1648.txt
# ✓ Saved: Account Activation Link_1649.txt
# ✓ Saved: IEEE Guwahati Subsection Conference 2025 : Submiss_1650.txt
# ✓ Saved: Sent ₹ 220 to  JAYAM RESTAURANT _1651.txt
# ✓ Saved: inhorizontech@gmail.com_1652.txt
# ✓ Saved: Sent ₹ 2054.5 to  IRCTC Web UPI _1653.txt
# ✓ Saved: Revision Required- TCE National Conclave 2025 - Pa_1654.txt
# ✓ Saved: Live Office Hours with TJ - March 20, 10:00 AM EST_1655.txt
# ✓ Saved: RCTCE 25 - Reviewers' Comments_1656.txt
# ✓ Saved: Huge Sale Discount on Communication Skills for Beg_1657.txt
# ✓ Saved: STUDENT HIRING - BECOME A CAMPUS AMBASSADOR_1658.txt
# ✓ Saved: CML 2025: Invitation to join Opening Ceremony_1659.txt
# ✓ Saved: Sent ₹ 2000 to  VIKKURTHI  SUJATHA _1660.txt
# ✓ Saved: CML 2025: Invitation to join Opening Ceremony_1661.txt
# ✓ Saved: Security alert_1662.txt
# ✗ Failed email b'1663': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: oceansvalley@gmail.com_1664.txt
# ✓ Saved: CML 2025: Invitation to join the 2nd day of the co_1665.txt
# ✓ Saved: Welcome to TCS iON_1666.txt
# ✓ Saved: Subscription Confirmation_1667.txt
# ✓ Saved: Notification of Paper Non-Acceptance -  Fifth IEEE_1668.txt
# ✓ Saved: Building PyTorch: Logs, Exponents, and Activation_1669.txt
# ✓ Saved: inhorizontech@gmail.com_1670.txt
# ✓ Saved: Paper Review Status Update _1671.txt
# ✓ Saved: Decision on your Paper Submission ID 718 _1672.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_1673.txt
# ✓ Saved: FINAL HOURS! Don't Miss Out 95% OFF - Hurry now!_1674.txt
# ✓ Saved: 🌙 Ramadan Special –_1675.txt
# ✓ Saved: Sent ₹ 120 to  G DHANUSH _1676.txt
# ✓ Saved: Sent ₹ 120 to  G DHANUSH _1677.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_1678.txt
# ✓ Saved: Security alert for kumar173setty@gmail.com_1679.txt
# ✓ Saved: Someone added you as their recovery email_1680.txt
# ✓ Saved: Congratulations! SETCOM 2025 - #64758 is now publi_1681.txt
# ✓ Saved: Live Office Hours - March 27, 10:00 AM EST_1682.txt
# ✓ Saved: properdotinstitute@gmail.com_1683.txt
# ✓ Saved: 70% OFF buy 1 Get 4 Course on Graphics and Office_1684.txt
# ✓ Saved: properdotinstitute@gmail.com_1685.txt
# ✓ Saved: 🚀_1686.txt
# ✓ Saved: 2-Step Verification turned on_1687.txt
# ✓ Saved: Security alert_1688.txt
# ✓ Saved: Security alert_1689.txt
# ✓ Saved: Security alert_1690.txt
# ✓ Saved: Payment for Airtel Mobile of ₹ 26 is successful_1691.txt
# ✓ Saved: Security alert_1692.txt
# ✓ Saved: Invitation: Interaction Session with Seniors @ Mon_1693.txt
#
# 📂 Processing folder: [Gmail]/Sent Mail
# ✗ Error in [Gmail]/Sent Mail: EXAMINE command error: BAD [b'Could not parse comm...
#
# 📂 Processing folder: [Gmail]/Spam
# ✗ Failed email b'1': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
#
# 📂 Processing folder: [Gmail]/Starred
# ✓ Saved: Fwd: Joint Entrance Examination (Main) - 2022 Scor_1.txt
# ✓ Saved: e-PAN allotment request submitted sucessfully_2.txt
# ✓ Saved: ePAN Allotted successfully_3.txt
# ✓ Saved: ePAN Allotted successfully_4.txt
# ✓ Saved: OTP for verification_5.txt
# ✓ Saved: Lenskart power_6.txt
# ✓ Saved: ISRO online training programme_7.txt
# ✓ Saved: Confirmation for Conducting IIRS Outreach Programm_8.txt
# ✓ Saved: TCS Recruitment: Registration Successful._9.txt
# ✓ Saved: International Conference on Sustainable Energy Tec_10.txt
# ✓ Saved: Congratulations your PA Insurance is issued for PN_11.txt
# ✓ Saved: IEEE SETCOM 2025 Conference Notification_12.txt
# ✓ Saved: International Conference on Sustainable Energy Tec_13.txt
# ✓ Saved: IEEE SETCOM 2025 Conference Notification_14.txt
# ✓ Saved: Hard Deadline: IEEE SETCOM 2025 Conference 21st to_15.txt
# ✓ Saved: International Conference on Sustainable Energy Tec_16.txt
# ✓ Saved: International Conference on Advances in Computer S_17.txt
# ✓ Saved: International Conference on Advances in Computer S_18.txt
# ✓ Saved: Hard Deadline: IEEE SETCOM 2025 Conference 21st to_19.txt
# ✓ Saved: 3rd International Conference on Advancement in Com_20.txt
# ✓ Saved: 2nd International Conference on Business Intellige_21.txt
# ✓ Saved: 2nd International Conference on Business Intellige_22.txt
# ✓ Saved: 2nd International Conference on Computing and Mach_23.txt
# ✗ Failed email b'24': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✗ Failed email b'25': [Errno 22] Invalid argument: 'c:\\Users\\aspk1\\On...
# ✓ Saved: ICEARS 2025 - Acceptance Letter_26.txt
# ✓ Saved: BIDA 2025 Notification for Paper ID 394_27.txt
# ✓ Saved: BIDA 2025 Notification for Paper ID 382_28.txt
# ✓ Saved: 6th International conference on Recent Trends in M_29.txt
# ✓ Saved: 6th International conference on Recent Trends in M_30.txt
# ✓ Saved: Notification of Your Paper ID 447 for Presentation_31.txt
# ✓ Saved: FIRST NATIONAL LEVEL RESEARCH CONCLAVE : Submissio_32.txt
# ✓ Saved: Notification of Your Paper ID 448 for Presentation_33.txt
# ✓ Saved: CML 2025 Notification for Paper ID 868_34.txt
# ✓ Saved: Fifth IEEE International Conference on Computing a_35.txt
# ✓ Saved: Heartfelt Thanks to All Authors and Reviewers _36.txt
# ✓ Saved: IEEE 4th International Conference on Advances in C_37.txt
# ✓ Saved: 2nd IEEE International Conference on Data Science _38.txt
# ✓ Saved: 2025 IEEE International conference on Research Met_39.txt
# ✓ Saved: 3rd IEEE International Conference on Computer, Ele_40.txt
# ✓ Saved: 3rd IEEE International Conference on Computer, Ele_41.txt
# ✓ Saved: IEEE Guwahati Subsection Conference 2025 : Submiss_42.txt
# ✓ Saved: IEEE 5th International Conference on Sustainable E_43.txt
# ✓ Saved: IEEE North-East India International Energy Convers_44.txt
# ✓ Saved: IEEE 5th International Conference on Sustainable E_45.txt
# ✓ Saved: Revision Required- TCE National Conclave 2025 - Pa_46.txt
# ✓ Saved: CML 2025: Invitation to join Opening Ceremony_47.txt
#
# ✅ All emails saved to: c:\Users\aspk1\OneDrive\Desktop\Gmail-Classification\Raw_Emails_TXT
